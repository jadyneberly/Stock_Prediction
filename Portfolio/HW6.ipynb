# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# ## Instructions

# %% [markdown]
# **Option 1**
#
# * Select a target TICKER among these options: ['AAPL','MSFT','AMZN','GOOG', 'WMT','JPM','TSLA','NFLX','ADBE'] (5 pts)
# * [HW6] Using DataWithSentimentsResults_HW.csv, predict the stock returns (do not use cumulative stock returns) of the target TICKER using sentiment scores from LSTM or Lexicon. (10 pts)
#     * You can also add lagged sentiment scores
#     * Choose any model (e.g., linear regression, gradient boosting, etc.)
# * Using SP500 stocks, calculate the stock returns of all the TICKERS ( 5 pts)
# * [HW2] Find top 5 stocks that are highly correlated with the target TICKER (5 pts)
# * [HW2] Use the returns of these stocks to predict the return of the target TICKER (10 pts)
#     * You can also add lagged returns of the correlated stocks
#     * Choose the same model (e.g., linear regression, gradient boosting, etc.)
# * [HW3] Calculate 5 technical indicators (5 pts)
# * [HW3] Use the technical indicators to predict the return of the target TICKER (10 pts)
#     * You can also add different periods of the same indicator
#     * Choose the same model (e.g., linear regression, gradient boosting, etc.)
# * [HW4] Find stocks that are in a pair with the target variable (5 pts)
#     * You can skip the clustering for this part
# * [HW4] Use the returns of the 5 stocks that are in a pair with the target variable to predict the return of the target variable ( 10 pts)
#     * You can also add lagged returns of the stocks
#     * Choose the same model (e.g., linear regression, gradient boosting, etc.)
# * [HW5] Using SP500 stocks, create PCA components (5 pts)
# * [HW5] Use the components (at least 95% variance explained) to predict the return of the target variable ( 10 pts)
# * Compare the strategies [HW6] vs [HW2] vs [HW3] vs [HW4] vs [HW5] (10 pts)
#     * Will combining them provide a better prediction ( 10 pts)
# * Save the best model (5 pts)
# * Rank the features by importance (5 pts)
# * Save the SHAP Explainer and create a SHAP plot (5 pts)
# * Deploy the model on AWS (10 pts)
# * Deploy the Streamlit app (10 pts)
#
# **Option 2**
#
# * Select a target TICKER among these options: ['AAPL','MSFT','AMZN','GOOG', 'WMT','JPM','TSLA','NFLX','ADBE'] (5 pts)
# * [HW6] Using DataWithSentimentsResults_HW.csv, predict the signal (BUY, HOLD, SELL) of the target TICKER using sentiment scores from LSTM or Lexicon. (10 pts)
#     * You can also add lagged sentiment scores
#     * Choose any model (e.g., logistic regression, gradient boosting, etc.)
# * Using SP500 stocks, calculate the stock returns of all the TICKERS ( 5 pts)
# * [HW2] Find top 5 stocks that are highly correlated with the target TICKER (5 pts)
# * [HW2] Use the returns of these stocks to predict the signal of the target TICKER (10 pts)
#     * You can also add lagged returns of the correlated stocks
#     * Choose the same model (e.g., logistic regression, gradient boosting, etc.)
# * [HW3] Calculate 5 technical indicators (5 pts)
# * [HW3] Use the technical indicators to predict the signal of the target TICKER (10 pts)
#     * You can also add different periods of the same indicator
#     * Choose the same model (e.g., logistic regression, gradient boosting, etc.)
# * [HW4] Find stocks that are in a pair with the target variable (5 pts)
#     * You can skip the clustering for this part
# * [HW4] Use the returns of the 5 stocks that are in a pair with the target variable to predict the signal of the target variable ( 10 pts)
#     * You can also add lagged returns of the stocks
#     * Choose the same model (e.g., logistic regression, gradient boosting, etc.)
# * [HW5] Using SP500 stocks, create PCA components (5 pts)
# * [HW5] Use the components (at least 95% variance explained) to predict the signal of the target variable ( 10 pts)
# * Compare the strategies [HW6] vs [HW2] vs [HW3] vs [HW4] vs [HW5] (10 pts)
#     * Will combining them provide a better prediction ( 10 pts)
# * Save the best model (5 pts)
# * Rank the features by importance (5 pts)
# * Save the SHAP Explainer and create a SHAP plot (5 pts)
# * Deploy the model on AWS (10 pts)
# * Deploy the Streamlit app (10 pts)
#
# **Option 3**
#
# * Using the dataset LabelledNewsData_HW.csv, preprocess the headlines (25 pts)
#     * Handling contractions (can't -> cannot) (5 pts)
#     *  Remove locations (e.g., New York), organizations (e.g., Apple), person names, dates, quantities, and monetary values using Naming Entity Recognition (5 pts)
#     *  Remove numbers and special characters (e.g., $20) (5 pts)
#     *  Keep Nouns and Verbs using Part of Speech Tagging (5 pts)
#     *  Lemmatize or stem the remaining tokens (5 pts)
# * Use Word2Vec to calculate the word embedding (10 pts)
# * Calculate the sentiment using 6 classifiers (10 pts)
#     * LogisticRegression()
#     * KNeighborsClassifier()
#     * DecisionTreeClassifier()
#     * SVC()
#     * MLPClassifier()
#     * RandomForestClassifier()
# * Choose the best classifier based on test accuracy (10 pts)
# * Use that classifier to calculate the sentiment of headlines from DataWithSentimentsResults_HW.csv (20 pts)
#     * You will need to preprocess and extract the word embedding of the headlines
#     * When importing the data, please note that the delimeter is "|"
# * Calculate the correlation between the sentiment you calculated and the stock returns (10 pts)
#     *  Is it a better correlation than the ones from the in-class exercise (see below)
#         *  correlation with sentiment lexicon: 0.16
#         *  correlation with sentiment LSTM: 0.1
#         *  correlation with sentiment Text blob: 0.05
# * Select a target TICKER among these options: ['AAPL','MSFT','AMZN','GOOG', 'WMT','JPM','TSLA','NFLX','ADBE'] (5 pts)
# * Using the sentiment you calculated, predict the stock returns (do not use cumulative stock returns) or the signal (BUY, HOLD, SELL) of the target TICKER. (10 pts)
#     * You can also add lagged sentiment scores
#     * Choose any model (e.g., linear regression, logistic regression, gradient boosting, etc.)
# * Save the model (5 pts)
# * Rank the features by importance (5 pts)
# * Save the SHAP Explainer and create a SHAP plot (5 pts)
# * Deploy the model on AWS (10 pts)
# * Deploy the Streamlit app (10 pts)
